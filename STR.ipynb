# %% [markdown]
# ## Single Quotes

# %%
a='apple'
print(a)
# Out:
# apple

# %% [markdown]
# ## Double Quotes

# %%
b="hello"
print(b)
# Out:
# hello

# %% [markdown]
# ## Triple Quotes

# %%
c="""python program is easy to learn
for begginer
in jupyter lab"""
print(c)
# Out:
# python program is easy to learn
# for begginer
# in jupyter lab

# %% [markdown]
# ## Type

# %%
"python"
type("python")
# Out:
# str

# %% [markdown]
# ## String Concatenation
# Whenever you add two strings, the strings are joined together as it is.

# %%
'happy'+'day'
# Out:
# 'happyday'

# %% [markdown]
# ## String Repetition
#
# Whenever you multiply a string with a number (int), the string is repeated the specified number of times.

# %%
'PYTHON'*4
# Out:
# 'PYTHONPYTHONPYTHONPYTHON'

# %% [markdown]
# ## Upper Case

# %%
d="wounderful"
d.upper()
# Out:
# 'WOUNDERFUL'

# %% [markdown]
# ## Lower Case

# %%
e="MONEY"
e.lower()
# Out:
# 'money'

# %% [markdown]
# ## Title Case

# %%
"data analytics".title()
# Out:
# 'Data Analytics'

# %% [markdown]
# ## Capitalize

# %%
"data analytics".capitalize()
# Out:
# 'Data analytics'

# %% [markdown]
# ## Startswith

# %%
"i like music".startswith("i")
# Out:
# True

# %%
"i like music".startswith("I")
# Out:
# False

# %% [markdown]
# ## Endswith

# %%
"mobile phone".endswith("phone")
# Out:
# True

# %%
"mobile phone".endswith("phone.")
# Out:
# False

# %% [markdown]
# ## Count

# %%
"mall".count("m")
# Out:
# 1

# %% [markdown]
# ## Find

# %%
"I want to learn python in easy method".find("to")
# Out:
# 7

# %% [markdown]
# ## Is Alpha

# %% [raw]
# # This is check all characters are only alphabets.
# # If the string has number,space,symbol it returns FALSE.

# %%
"coimbatore".isalpha()
# Out:
# True

# %%
"Happy New Year 2020".isalpha()
# Out:
# False

# %% [markdown]
# ## Is Numeric

# %%
"2026".isnumeric()
# Out:
# True

# %%
"Happy New Year 2026".isnumeric()
# Out:
# False

# %% [markdown]
# ## Strip
# #it is remove the space

# %%
"   coimbatore   ".strip()
# Out:
# 'coimbatore'

# %%
"   cup   cake".lstrip()
# Out:
# 'cup   cake'

# %%
"cup   cake   ".rstrip()
# Out:
# 'cup   cake'

# %% [markdown]
# ### Get a information from users

# %%
name = input("Enter your name: ")
print("Your name is:", name)
# Out:
# Enter your name:  gayu
# Your name is: gayu
